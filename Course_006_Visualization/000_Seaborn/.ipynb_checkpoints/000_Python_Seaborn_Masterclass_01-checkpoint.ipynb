# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: numpy>=1.15 in c:\users\ashwin\appdata\roaming\python\python39\site-packages (from seaborn) (1.21.4)
#
# ...

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
type(sns.load_dataset('anagrams'))
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = sns.load_dataset('anagrams')

# %%
df1.tail()
# Out:
#     subidr    attnr  num1  num2  num3
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
from IPython.display import Image
Image(filename='function_overview_8_0.png')

# %%
# https://seaborn.pydata.org/tutorial/function_overview.html

# %% [markdown]
# # Scatterplot

# %%
# %matplotlib inline

# %%
pip install pandas matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip")
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue="time",
               style="time")
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue="time")
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", style="time")
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue="day",
               style="time")
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue="size")
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue="size",
               palette="deep")
plt.show()

# %%
tip_rate = tips.eval("tip/total_bill").rename("tip_rate")

# %%
tip_rate
# Out:
# 0      0.059447
# 1      0.160542
# 2      0.166587
# 3      0.139780
# 4      0.146808
#          ...
# 239    0.203927
# 240    0.073584
# 241    0.088222
# 242    0.098204
# 243    0.159744
# Name: tip_rate, Length: 244, dtype: float64

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue=tip_rate)
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue="size",
               size="size")
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue="size",
               size="size", sizes=(20, 200))
               #,legend="full")
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", hue="size",
               size="size", 
                sizes=(20, 200),
               hue_norm=(0, 7))
plt.show()

# %%
markers = {"Lunch": "s", "Dinner":"X"}
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", style="time", markers= markers)
plt.show()

# %%
sns.scatterplot(data=tips,
               x="total_bill",
               y="tip", s=100, 
                marker= "+",
               color=".2")
plt.show()

# %%
index = pd.date_range("1/1/2020", periods=100,
                     freq="m", name="date")
data = np.random.randn(100, 4).cumsum(axis=0)
wide_df = pd.DataFrame(data, index, ["a", "b", "c", "d"])
sns.scatterplot(data=wide_df)
plt.show()

# %%
sns.relplot(data=tips,
               x="total_bill",
               y="tip",col="time",
            hue="day", style="day", 
            kind="scatter")
plt.show()

# %%
sns.relplot(data=tips,
               x="total_bill",
               y="tip")
plt.show()

# %% [markdown]
# # Histogram

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm")
plt.show()

# %%
sns.histplot(data=penguins,
            x="bill_length_mm")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            binwidth=1)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            binwidth=3)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            binwidth=5)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            bins=30)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            kde=True)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            multiple="stack")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            element="step")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            element="poly")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            element="step",
            stat="density",
            common_norm=False)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            element="step",
            stat="density",
            common_norm=True)
plt.show()

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=tips, x ="size",
            stat="percent",
            discrete=True)
plt.show()

# %%
sns.histplot(data=tips, 
             x ="day",
            shrink=0.8)
plt.show()

# %%
sns.histplot(data=tips, 
             x ="day", hue="sex",
            shrink=0.8, multiple="dodge")
plt.show()

# %%
planets = sns.load_dataset("planets")

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.histplot(data=planets,
            x="distance")
plt.show()

# %%
sns.histplot(data=planets,
            x="distance",
            log_scale=True)
plt.show()

# %%
sns.histplot(data=planets,
            x="distance",
            log_scale=True,
            fill=False)
plt.show()

# %%
sns.histplot(data=planets,
            x="distance",
            log_scale=True,
            element="step",
            fill=False)
plt.show()

# %%
sns.histplot(penguins, 
             y="body_mass_g",
            x="bill_depth_mm")
plt.show()

# %%
sns.histplot(penguins, 
             y="body_mass_g",
            x="bill_depth_mm",
            hue="species")
plt.show()

# %%
sns.histplot(data=planets, 
             y="distance",
            x="year", bins=30,
            discrete=(True, False),
            log_scale=(False, True))
plt.show()

# %%
sns.histplot(data=planets, 
             y="distance",
            x="year", bins=30,
            discrete=(True, False),
            log_scale=(False, True), 
             thresh=None)
plt.show()

# %%
sns.histplot(data=planets, 
             y="distance",
            x="year", bins=30,
            discrete=(True, False),
            log_scale=(False, True), 
             pthresh=0.5, pmax=0.9)
plt.show()

# %%
sns.histplot(data=planets, 
             y="distance",
            x="year", bins=30,
            discrete=(True, False),
            log_scale=(False, True), 
             cbar=True, 
             cbar_kws=dict(shrink=0.75))
plt.show()

# %% [markdown]
# # KDE (Kernel Density Estimate)

# %%
tips = sns.load_dataset("tips")

# %%
sns.kdeplot(data=tips, 
            x="total_bill")
plt.show()

# %%
sns.kdeplot(data=tips, 
            y="total_bill")
plt.show()

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data=iris)
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           bw_adjust=0.2)
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           bw_adjust=5, cut=0)
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           hue="time")
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           hue="time", multiple="stack")
plt.show()

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.kdeplot(data=diamonds, x="price",
           log_scale=True)
plt.show()

# %%
sns.kdeplot(data=tips, 
            x="total_bill",
           hue="size")
plt.show()

# %%
sns.kdeplot(data=tips, 
            x="total_bill",
           hue="size", fill=True,
           common_norm=False,
           palette="crest",
           alpha=0.5, linewidth=0)
plt.show()

# %%
geyser = sns.load_dataset("geyser")

# %%
geyser
# Out:
#      duration  waiting   kind
# 0       3.600       79   long
# 1       1.800       54  short
# 2       3.333       74   long
# 3       2.283       62  short
# 4       4.533       85   long
# ..        ...      ...    ...
# 267     4.117       81   long
# 268     2.150       46  short
# 269     4.417       90   long
# 270     1.817       46  short
# 271     4.467       74   long
#
# [272 rows x 3 columns]

# %%
sns.kdeplot(data=geyser, x= "waiting", y="duration")
plt.show()

# %%
sns.kdeplot(data=geyser, x= "waiting", 
            y="duration", hue="kind")
plt.show()

# %%
sns.kdeplot(data=geyser, x= "waiting", 
            y="duration", hue="kind",
           fill=True)
plt.show()

# %%
sns.kdeplot(data=geyser, x= "waiting", 
            y="duration", hue="kind",
           levels=5, thresh=.2)
plt.show()

# %%
sns.kdeplot(data=geyser, x= "waiting", 
            y="duration", hue="kind",
           levels=100, thresh=0,
           cmap="mako")
plt.show()
# Out:
# C:\Users\Ashwin\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:1163: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(data=geyser, x= "waiting", 
            y="duration", fill=True,
           levels=100, thresh=0,
           cmap="mako")
plt.show()

# %% [markdown]
# # Rugplot

# %%
sns.set_theme()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(data=tips, x="total_bill")
sns.rugplot(data=tips, x="total_bill")
plt.show()

# %%
sns.rugplot(data=tips, x="total_bill")
plt.show()

# %%
sns.scatterplot(data=tips, y="tip", x="total_bill")
sns.rugplot(data=tips, y="tip", x="total_bill")
plt.show()

# %%
sns.scatterplot(data=tips, y="tip", x="total_bill", hue="time")
sns.rugplot(data=tips, y="tip", x="total_bill", hue="time")
plt.show()

# %%
sns.scatterplot(data=tips, y="tip", x="total_bill", hue="time")
sns.rugplot(data=tips, y="tip", x="total_bill", hue="time", height=.1)
plt.show()

# %%
sns.scatterplot(data=tips, y="tip", 
                x="total_bill", hue="time")
sns.rugplot(data=tips, y="tip", x="total_bill", 
            hue="time", height=-0.2,
           clip_on=False)
plt.show()

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.scatterplot(data=diamonds, y="price", 
                x="carat", s=5)
sns.rugplot(data=diamonds, y="price", 
                x="carat", lw=1, 
            alpha=0.005)
plt.show()

# %% [markdown]
# # Countplot

# %%
sns.set_theme(style="darkgrid")

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(data=titanic)
plt.show()

# %%
sns.countplot(data=titanic,
             x="class")
plt.show()

# %%
sns.countplot(data=titanic,
             x="class", hue="who")
plt.show()

# %%
sns.countplot(data=titanic,
             y="class", hue="who")
plt.show()

# %%
sns.countplot(data=titanic,
             palette="Set3", 
              x="who")
plt.show()

# %%
sns.countplot(data=titanic,
             facecolor=(0, 0, 0, 0), 
              x="who", linewidth=5,
             edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
sns.catplot(data=titanic, hue="who",
              x="class", col="survived",
             kind="count", 
             aspect=0.7, height=4)
plt.show()

# %% [markdown]
# # Regplot

# %%
sns.set_theme(color_codes=True)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(x="total_bill",
           y="tip", data=tips)
plt.show()

# %%
np.random.seed(8)
mean, cov = [4, 6], [(1.5, .7), (.7, 1)]
x, y = np.random.multivariate_normal(mean, cov, 80).T
sns.regplot(x=x, y=y, color="g")
plt.show()

# %%
x = pd.Series(x, name="x_var")
x = pd.Series(y, name="y_var")
sns.regplot(x=x, y=y, marker="+")
plt.show()

# %%
sns.regplot(x=x, y=y, ci=68, truncate=False)
plt.show()

# %%
sns.regplot(data=tips, x="size",
           y="total_bill", x_jitter=0.1)
plt.show()

# %%
sns.regplot(data=tips, x="size",
           y="total_bill", x_estimator=np.mean)
plt.show()

# %%
ans = sns.load_dataset("anscombe")

# %%
ans
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
sns.regplot(x="x", y="y",
           data=ans.loc[ans.dataset == "II"],
           scatter_kws={"s": 80},
           order=2, ci=None)
plt.show()

# %% [markdown]
# # Controlling figure Aesthetics

# %%
def sinplot(flip=1):
    x = np.linspace(0 , 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * 0.5) * ( 7 - i ) * flip)

# %%
sinplot()

# %%
# Seaborn Default
sns.set_theme()
sinplot()

# %% [markdown]
# ## Seaborn Figure Styles

# %%
sns.set_style("whitegrid")
sinplot()

# %%
sns.set_style("dark")
sinplot()

# %%
sns.set_style("white")
sinplot()

# %%
sns.set_style("ticks")
sinplot()

# %% [markdown]
# ## Removing axes spines

# %%
sinplot()
sns.despine()

# %%
sinplot()
sns.despine(offset = 10, trim = True)

# %%
sinplot()
sns.despine(left= True)

# %%
f = plt.figure(figsize=(6, 6))
gs = f.add_gridspec(2, 2)

with sns.axes_style("darkgrid"):
    ax = f.add_subplot(gs[0, 0])
    sinplot()

with sns.axes_style("white"):
    ax = f.add_subplot(gs[0, 1])
    sinplot()

with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[1, 0])
    sinplot()
    
with sns.axes_style("whitegrid"):
    ax = f.add_subplot(gs[1, 1])
    sinplot()
    
f.tight_layout()
plt.show()

# %% [markdown]
# # lmplot

# %%
sns.set_theme(color_codes=True)

# %%
tips=sns.load_dataset("tips")

# %%
sns.lmplot(data=tips)
plt.show()

# %%
sns.lmplot(data=tips, y='tip',
          x="total_bill")
plt.show()

# %%
sns.lmplot(data=tips, y='tip',
          x="total_bill",
          hue="smoker")
plt.show()

# %%
sns.lmplot(data=tips, y='tip',
          x="total_bill",
          hue="smoker",
          markers=['o', 'x'])
plt.show()

# %%
sns.lmplot(data=tips, y='tip',
          x="total_bill",
          hue="smoker",
           palette="Set1",
          markers=['o', 'x'])
plt.show()

# %%
sns.lmplot(data=tips, y='tip',
          x="total_bill",
          hue="smoker",
           palette=dict(Yes="g", No="r"),
          markers=['o', 'x'])
plt.show()

# %%
sns.lmplot(data=tips, y='tip',
          x="total_bill",
          col="smoker")
plt.show()

# %%
sns.lmplot(data=tips, y='total_bill',
          x="size", hue = "day",
          col="day", aspect=0.4, 
           x_jitter=0.1)
plt.show()

# %%
sns.lmplot(data=tips, x='total_bill',
          y="tip", hue = "day",
          col="day", col_wrap=2, 
           height=3)
plt.show()

# %%
sns.lmplot(data=tips, x='total_bill',
          y="tip", row = "sex",
          col="time", height=3)
plt.show()
